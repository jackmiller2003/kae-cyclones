# %% [markdown]
# ## Measure-Preserving Systems

# %% [markdown]
# Measure-preserving systems obey the Poincaré recurrence theorem, and are a special case of conservative systems. They provide the formal, mathematical basis for a broad range of physical systems, and, in particular, many systems from classical mechanics (in particular, most non-dissipative systems) as well as systems in thermodynamic equilibrium.
#
# We wish to discover if there is a relationship between the dissipative element of a system and the utility of eigenvalue penalties and initialisation. That is, if we are able to capture the non-dissipative element for prediction.

# %% [markdown]
# ### Damped Driven Pendulum

# %% [markdown]
# We hypothesis that as the damping increases, the utility of the penalty and initialisation will increase.

# %%
import scipy
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import math
import numpy as np

def simple_pendulum_deriv(x, t, m, g, l, F, c, omega): 
# The simple pendulum subject to zero damping and zero control input 
    nx = np.zeros(2)
    nx[0] = x[1]
    nx[1] = (1/m) * (F * math.sin(omega * t) - (m * g / l) * x[0] - c * nx[0])
    return nx

t_span = np.linspace(0,20,200)

sol = odeint(simple_pendulum_deriv, y0=[0,0.5], t=t_span, args=(1,9.8,1,0.6,0.5,1))
y = sol[:,0]
y_dot = sol[:,1]

# %%
plt.plot(t_span, y)
plt.plot(t_span, y_dot)
plt.show()

# %% [markdown]
# ### Testing Cyclone Examples

# %% [markdown]
# There is a known result that if the divergence of vector fields are non-zero the system is not measure preserving.

# %%
import xarray
import metpy.calc
import windspharm.xarray

# %%
import json
train_json_path = '/g/data/x77/ob2720/partition/train.json'

with open(train_json_path, 'r') as tj:
    tj_dict = json.load(tj)

# %%
divs = []

for i, cyclone, data in enumerate(tj_dict.items()):
    if i % 100 == 0:
        cyclone_coords = tj_dict[cyclone]['coordinates']
        ds = xarray.open_mfdataset(f"/g/data/x77/ob2720/partition/train/{cyclone}.nc")
        u = ds.u[dict(time=int(len(ds.time)/2), level=2)]
        v = ds.v[dict(time=int(len(ds.time)/2), level=2)]
        new_lat = u.latitude/4 + cyclone_coords[i][1] - 20
        new_lon = u.longitude/4 + cyclone_coords[i][0] - 20
        dx, dy = metpy.calc.lat_lon_grid_deltas(longitude=new_lon.values, latitude=new_lat.values)
        div = metpy.calc.divergence(u, v, dx=dx, dy=dy)

# %%
cyclone_coords = tj_dict['1999258N25128']['coordinates']
print(cyclone_coords)
# Out:
# [[128.4, 25.3], [129.09, 25.9511], [129.5, 26.3], [129.393, 26.4315], [129.225, 26.5], [129.238, 26.641], [129.255, 26.8364], [129.177, 27.1334], [129.067, 27.5333], [129.047, 28.0132], [128.962, 28.5154], [128.626, 29.0259], [128.24, 29.4], [127.926, 29.5413], [127.65, 29.575], [127.46, 29.6324], [127.3, 29.675], [127.16, 29.7052], [127.0, 29.725], [126.758, 29.7557], [126.5, 29.775], [126.294, 29.7624], [126.1, 29.75], [125.882, 29.7675], [125.675, 29.8], [125.539, 29.8205], [125.35, 29.875], [124.987, 29.9903], [124.575, 30.15], [124.244, 30.3129], [123.925, 30.525], [123.581, 30.8062], [123.225, 31.125], [122.849, 31.4244], [122.487, 31.7533], [122.153, 32.1125], [121.969, 32.5308], [122.043, 33.069], [122.3, 33.6], [122.589, 34.0287], [123.033, 34.3333], [123.732, 34.5086], [124.4, 34.5667], [124.737, 34.5695], [124.9, 34.53], [125.022, 34.4925], [125.14, 34.42], [125.063, 34.1228], [125.4, 33.9]]

# %%
ds = xarray.open_mfdataset("/g/data/x77/ob2720/partition/train/1999258N25128.nc")

# %%
len(ds.time)
# Out:
# 49

# %%
u = ds.u[dict(time=20, level=2)]
v = ds.v[dict(time=20, level=2)]

# %%
u
# Out:
# <xarray.DataArray 'u' (latitude: 160, longitude: 160)>
# dask.array<getitem, shape=(160, 160), dtype=float32, chunksize=(160, 160), chunktype=numpy.ndarray>
# Coordinates:
#     level    int32 650
#     time     datetime64[ns] 1999-09-17
# Dimensions without coordinates: latitude, longitude
# Attributes:
#     units:          m s**-1
#     long_name:      U component of wind
#     standard_name:  eastward_wind

# %%
new_lat = u.latitude/4 + cyclone_coords[0][1] - 20
new_lon = u.longitude/4 + cyclone_coords[0][0] - 20

# %%
new_lat
# Out:
# <xarray.DataArray 'latitude' (latitude: 160)>
# array([ 5.3 ,  5.55,  5.8 ,  6.05,  6.3 ,  6.55,  6.8 ,  7.05,  7.3 ,
#         7.55,  7.8 ,  8.05,  8.3 ,  8.55,  8.8 ,  9.05,  9.3 ,  9.55,
#         9.8 , 10.05, 10.3 , 10.55, 10.8 , 11.05, 11.3 , 11.55, 11.8 ,
#        12.05, 12.3 , 12.55, 12.8 , 13.05, 13.3 , 13.55, 13.8 , 14.05,
#        14.3 , 14.55, 14.8 , 15.05, 15.3 , 15.55, 15.8 , 16.05, 16.3 ,
#        16.55, 16.8 , 17.05, 17.3 , 17.55, 17.8 , 18.05, 18.3 , 18.55,
#        18.8 , 19.05, 19.3 , 19.55, 19.8 , 20.05, 20.3 , 20.55, 20.8 ,
#        21.05, 21.3 , 21.55, 21.8 , 22.05, 22.3 , 22.55, 22.8 , 23.05,
#        23.3 , 23.55, 23.8 , 24.05, 24.3 , 24.55, 24.8 , 25.05, 25.3 ,
#        25.55, 25.8 , 26.05, 26.3 , 26.55, 26.8 , 27.05, 27.3 , 27.55,
#        27.8 , 28.05, 28.3 , 28.55, 28.8 , 29.05, 29.3 , 29.55, 29.8 ,
#        30.05, 30.3 , 30.55, 30.8 , 31.05, 31.3 , 31.55, 31.8 , 32.05,
#        32.3 , 32.55, 32.8 , 33.05, 33.3 , 33.55, 33.8 , 34.05, 34.3 ,
#        34.55, 34.8 , 35.05, 35.3 , 35.55, 35.8 , 36.05, 36.3 , 36.55,
#        36.8 , 37.05, 37.3 , 37.55, 37.8 , 38.05, 38.3 , 38.55, 38.8 ,
#        39.05, 39.3 , 39.55, 39.8 , 40.05, 40.3 , 40.55, 40.8 , 41.05,
#        41.3 , 41.55, 41.8 , 42.05, 42.3 , 42.55, 42.8 , 43.05, 43.3 ,
#        43.55, 43.8 , 44.05, 44.3 , 44.55, 44.8 , 45.05])
# Coordinates:
#     level    int32 650
#     time     datetime64[ns] 1999-09-17
# Dimensions without coordinates: latitude

# %%
new_lon
# Out:
# <xarray.DataArray 'longitude' (longitude: 160)>
# array([108.4 , 108.65, 108.9 , 109.15, 109.4 , 109.65, 109.9 , 110.15,
#        110.4 , 110.65, 110.9 , 111.15, 111.4 , 111.65, 111.9 , 112.15,
#        112.4 , 112.65, 112.9 , 113.15, 113.4 , 113.65, 113.9 , 114.15,
#        114.4 , 114.65, 114.9 , 115.15, 115.4 , 115.65, 115.9 , 116.15,
#        116.4 , 116.65, 116.9 , 117.15, 117.4 , 117.65, 117.9 , 118.15,
#        118.4 , 118.65, 118.9 , 119.15, 119.4 , 119.65, 119.9 , 120.15,
#        120.4 , 120.65, 120.9 , 121.15, 121.4 , 121.65, 121.9 , 122.15,
#        122.4 , 122.65, 122.9 , 123.15, 123.4 , 123.65, 123.9 , 124.15,
#        124.4 , 124.65, 124.9 , 125.15, 125.4 , 125.65, 125.9 , 126.15,
#        126.4 , 126.65, 126.9 , 127.15, 127.4 , 127.65, 127.9 , 128.15,
#        128.4 , 128.65, 128.9 , 129.15, 129.4 , 129.65, 129.9 , 130.15,
#        130.4 , 130.65, 130.9 , 131.15, 131.4 , 131.65, 131.9 , 132.15,
#        132.4 , 132.65, 132.9 , 133.15, 133.4 , 133.65, 133.9 , 134.15,
#        134.4 , 134.65, 134.9 , 135.15, 135.4 , 135.65, 135.9 , 136.15,
#        136.4 , 136.65, 136.9 , 137.15, 137.4 , 137.65, 137.9 , 138.15,
#        138.4 , 138.65, 138.9 , 139.15, 139.4 , 139.65, 139.9 , 140.15,
#        140.4 , 140.65, 140.9 , 141.15, 141.4 , 141.65, 141.9 , 142.15,
#        142.4 , 142.65, 142.9 , 143.15, 143.4 , 143.65, 143.9 , 144.15,
#        144.4 , 144.65, 144.9 , 145.15, 145.4 , 145.65, 145.9 , 146.15,
#        146.4 , 146.65, 146.9 , 147.15, 147.4 , 147.65, 147.9 , 148.15])
# Coordinates:
#     level    int32 650
#     time     datetime64[ns] 1999-09-17
# Dimensions without coordinates: longitude

# %%
dx, dy = metpy.calc.lat_lon_grid_deltas(longitude=new_lon.values, latitude=new_lat.values)

# %%
div = metpy.calc.divergence(u, v, dx=dx, dy=dy)

# %%
div
# Out:
# <xarray.DataArray (latitude: 160, longitude: 160)>
# <Quantity([[ 9.56369199e-05  8.85927621e-05  7.92146979e-05 ...  9.03642359e-06
#    7.93207301e-06  6.48228385e-06]
#  [ 8.84561961e-05  8.14678538e-05  6.92612317e-05 ...  2.54785649e-06
#    7.45560216e-07  4.00587985e-07]
#  [ 6.68655113e-05  6.36171219e-05  5.65015877e-05 ... -3.21268879e-06
#   -5.86018423e-06 -7.32371599e-06]
#  ...
#  [ 1.23622344e-05  4.35410402e-06 -2.87960819e-06 ... -3.13142554e-05
#   -3.22530956e-05 -3.19377408e-05]
#  [ 6.39258892e-06  5.88060327e-06  7.27555633e-07 ... -2.78833418e-05
#   -2.37458787e-05 -1.91667569e-05]
#  [ 3.82793987e-06  4.92253049e-06  8.57831244e-07 ... -2.10879138e-05
#   -1.19860232e-05 -4.97112532e-06]], '1 / second')>
# Coordinates:
#     level    int32 650
#     time     datetime64[ns] 1999-09-17
# Dimensions without coordinates: latitude, longitude

# %%
import seaborn

# %%
seaborn.heatmap(div.values * 10800)
# Out:
# <AxesSubplot:>
