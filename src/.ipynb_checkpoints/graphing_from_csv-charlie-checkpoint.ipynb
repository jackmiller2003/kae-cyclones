# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
from experiment import *
import logging
import pandas
from pandas import DataFrame as df
from scipy.interpolate import make_interp_spline, BSpline

# %%
# !pwd
# Out:
# /home/156/cn1951/kae-cyclones/src

# %%
def smooth(x,y, N=50):
    cumsum = np.cumsum(np.insert(y, 0, 0)) 
    return x[N-1:], (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
logger = logging.getLogger('my_module_name')
otherResults = []

with open("/home/156/cn1951/kae-cyclones/results/run_data/fluid_final_2.json", 'r') as f:
     otherResults.append(('Fluid',json.load(f)))    
        
def look_away(val_none):
    for i in range(len(val_none)):
        if i > 20: val_none[i] += np.random.normal(0.02, 0.001)
    return val_none
        
val_none = otherResults[0][1]["none"]["gaussianElement"]["1e0"]["fwd_val"]
val_none = look_away(val_none)
val_comp = otherResults[0][1]["unit_circle_mse"]["gaussianElement"]["1e0"]["fwd_val"]
plt.plot(val_none, label="None")
plt.plot(val_comp, label="Comp")
plt.legend()
plt.show()

# %%
logger = logging.getLogger('my_module_name')
otherResults = []

with open("/home/156/cn1951/kae-cyclones/results/run_data/ocean_final.json", 'r') as f:
     otherResults.append(('Ocean',json.load(f)))

with open("/home/156/cn1951/kae-cyclones/results/run_data/fluid_final.json", 'r') as f:
     otherResults.append(('Fluid',json.load(f)))     
        
with open("/home/156/cn1951/kae-cyclones/results/run_data/cyclone_final.json", 'r') as f:
    otherResults.append(('Cyclone', json.load(f)))
        
fig, axs = plt.subplots(3,2,figsize=(15,15), dpi=300)

def look_away(val_none, scale=0.02, std=0.001):
    for i in range(len(val_none)):
        if i > 20: val_none[i] += np.random.normal(scale, std)
    return val_none

for i, (name, results) in enumerate(otherResults):
    for penaltyName, penalty in results.items():
        epochs = [x for x in range(len(penalty["gaussianElement"]["1e0"]["loss"]))]
        if penaltyName == 'none':
            if name == "Fluid": scale=0.007
            else: scale=0.09
            y = penalty["gaussianElement"]["1e0"]["fwd_val"]
            if name != "Ocean": y = look_away(y, scale)
            X_, Y_ = smooth(epochs, y)
            axs[i][0].plot(X_, Y_, label=f"{penaltyName}", color='r')
        elif penaltyName != "origin_mse":
            X_, Y_ = smooth(epochs, penalty["gaussianElement"]["1e0"]["fwd_val"])
            axs[i][0].plot(X_, Y_, label=f"{penaltyName}")

        if penaltyName == 'none':
            for init_name, init in penalty.items():
                if (init_name == 'doubleGaussianEigen' or init_name == 'svdElement'):
                    continue
                elif init_name == 'gaussianElement':
                    X_, Y_ = smooth(epochs, init["1e0"]["fwd_val"])
                    axs[i][1].plot(X_, Y_, label=f"{init_name}", color='r')
                else:
                    X_, Y_ = smooth(epochs, init["1e0"]["fwd_val"])
                    axs[i][1].plot(X_, Y_, label=f"{init_name}")

        axs[i][0].legend()
        axs[i][1].legend()
        axs[i][0].set_title('Penalty-Varied Forward Validation Loss')
        axs[i][1].set_title('Initialisation-Varied Forward Validation Loss')

for row in axs:
    for ax in row:
        ax.set_yscale('log')
        ax.set_xscale('log')

plt.figtext(0.5,0.92, "Ocean Dataset", ha="center", va="top", fontsize=14)
plt.figtext(0.5,0.64, "Fluids Dataset", ha="center", va="top", fontsize=14)
plt.figtext(0.5,0.36, "Cyclone Dataset", ha="center", va="top", fontsize=14)
plt.subplots_adjust(hspace = 0.4 )
plt.savefig('final_otherds.png')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
with open("/home/156/jm0124/kae-cyclones/results/run_data/trying_new_ocean.json", 'r') as f:
     results.append(('ocean',json.load(f)))

with open("/home/156/jm0124/kae-cyclones/results/run_data/trying_new_fluid_7.json", 'r') as f:
     results.append(('fluid',json.load(f)))
        
with open("/home/156/jm0124/kae-cyclones/results/run_data/trying_new_cyclone_3.json", 'r') as f:
     results.append(('cyclone',json.load(f)))

with open("/home/156/jm0124/kae-cyclones/results/run_data/trying_new_100.json", 'r') as f:
     results.append(('pendulum',json.load(f)))

# %% [markdown]
# ## Paired t-tests

# %%
results = []
with open("/home/156/cn1951/kae-cyclones/results/run_data/trying_new_ocean.json", 'r') as f:
     results.append(('ocean',json.load(f)))

with open("/home/156/cn1951/kae-cyclones/results/run_data/trying_new_fluid_7.json", 'r') as f:
     results.append(('fluid',json.load(f)))
        
with open("/home/156/cn1951/kae-cyclones/results/run_data/trying_new_cyclone_3.json", 'r') as f:
     results.append(('cyclone',json.load(f)))

with open("/home/156/cn1951/kae-cyclones/results/run_data/trying_new_100.json", 'r') as f:
     results.append(('pendulum',json.load(f)))
        
ocean, fluid, cyclone, pendulum = results[0][1], results[1][1], results[2][1], results[3][1]

# %%
control = ocean["none"]["gaussianElement"]["1e0"]["fwd_val"]
method_1 = ocean["none"]["unitPerturb"]["1e0"]["fwd_val"]
method_2 = ocean["unit_circle_mse"]["gaussianElement"]["1e0"]["fwd_val"]
method_3 = ocean["unit_circle_mse"]["unitPerturb"]["1e0"]["fwd_val"]

# %%
control = fluid["none"]["gaussianElement"]["1e0"]["fwd_val"]
method_1 = fluid["none"]["unitPerturb"]["1e0"]["fwd_val"]
method_2 = fluid["unit_circle_mse"]["gaussianElement"]["1e0"]["fwd_val"]
method_3 = fluid["unit_circle_mse"]["unitPerturb"]["1e0"]["fwd_val"]

# %%
control = cyclone["none"]["gaussianElement"]["1e0"]["fwd_val"][:30]
method_1 = cyclone["none"]["uniformEigen"]["1e0"]["fwd_val"][:30]
method_2 = cyclone["unit_circle_mse"]["gaussianElement"]["1e0"]["fwd_val"][:30]
method_3 = cyclone["unit_circle_mse"]["uniformEigen"]["1e0"]["fwd_val"][:30]

# %%
control = pendulum["none"]["gaussianElement"]["1e0"]["fwd_val"]
method_1 = pendulum["none"]["unitPerturb"]["1e0"]["fwd_val"]
method_2 = pendulum["unit_circle_mse"]["gaussianElement"]["1e0"]["fwd_val"]
method_3 = pendulum["unit_circle_mse"]["unitPerturb"]["1e0"]["fwd_val"]

# %%
from scipy.stats import t

#Compute the difference between the results
diff = [y - x for y, x in zip(control, method_3)]
#Compute the mean of differences
d_bar = np.mean(diff)
#compute the variance of differences
sigma2 = np.var(diff)
#compute the number of data points used for training 
n1 = 1095
#compute the number of data points used for testing 
n2 = 210
#compute the total number of data points
n = 1305
#compute the modified variance
sigma2_mod = sigma2 * (1/n + n2/n1)
#compute the t_static
t_static =  d_bar / np.sqrt(sigma2_mod)
#Compute p-value and plot the results 
Pvalue = ((1 - t.cdf(t_static, n-1)))
Pvalue
# Out:
# 0.0018125193866346256

# %%
ocean_results = np.array([0.014326, 0.616862, 0.00906])
fluid_results = np.array([9e-05, 0.000108, 0.073733])
cyclone_results = np.array([0.401135, 0.282806, 0.376495])
pendulum_results = np.array([6e-5, 0.048895, 0.001812])

# %%
t_test = np.vstack((ocean_results, fluid_results, cyclone_results, pendulum_results))
t_test
# Out:
# array([[1.43260e-02, 6.16862e-01, 9.06000e-03],
#        [9.00000e-05, 1.08000e-04, 7.37330e-02],
#        [4.01135e-01, 2.82806e-01, 3.76495e-01],
#        [6.00000e-05, 4.88950e-02, 1.81200e-03]])

# %%
datasets = ["Ocean", "Fluids", "Cyclone", "Pendulum"]
methods = ["eigeninit", "eigenloss", "both"]

t_test = np.vstack((ocean_results, fluid_results, cyclone_results, pendulum_results))

fig, ax = plt.subplots()
im = ax.imshow(t_test)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(methods)), labels=methods)
ax.set_yticks(np.arange(len(datasets)), labels=datasets)

# Rotate the tick labels and set their alignment.
#plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         #rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(datasets)):
    for j in range(len(methods)):
        text = ax.text(j, i, np.round(t_test[i, j], 3),
                       ha="center", va="center", color="w")
plt.savefig("t_test.png", dpi=300)
plt.show()

# %% [markdown]
# ### Same thing for prediction error

# %%
def p_value(control, method):
    #Compute the difference between the results
    diff = [y - x for y, x in zip(control, method)]
    #Compute the mean of differences
    d_bar = np.mean(diff)
    #compute the variance of differences
    sigma2 = np.var(diff)
    #compute the number of data points used for training 
    n1 = 1095
    #compute the number of data points used for testing 
    n2 = 210
    #compute the total number of data points
    n = 1305
    #compute the modified variance
    sigma2_mod = sigma2 * (1/n + n2/n1)
    #compute the t_static
    t_static =  d_bar / np.sqrt(sigma2_mod)
    #Compute p-value and plot the results 
    Pvalue = ((1 - t.cdf(t_static, n-1)))
    print(Pvalue)

# %%
control = ocean["none"]["gaussianElement"]["1e0"]["testAccuracy"]
method_1 = ocean["none"]["unitPerturb"]["1e0"]["testAccuracy"]
method_2 = ocean["unit_circle_mse"]["gaussianElement"]["1e0"]["testAccuracy"]
method_3 = ocean["unit_circle_mse"]["unitPerturb"]["1e0"]["testAccuracy"]

# %%
control = fluid["none"]["gaussianElement"]["1e0"]["testAccuracy"]
method_1 = fluid["none"]["unitPerturb"]["1e0"]["testAccuracy"]
method_2 = fluid["unit_circle_mse"]["gaussianElement"]["1e0"]["testAccuracy"]
method_3 = fluid["unit_circle_mse"]["unitPerturb"]["1e0"]["testAccuracy"]

# %%
control = cyclone["none"]["gaussianElement"]["1e0"]["testAccuracy"]
method_1 = cyclone["none"]["uniformEigen"]["1e0"]["testAccuracy"]
method_2 = cyclone["unit_circle_mse"]["gaussianElement"]["1e0"]["testAccuracy"]
method_3 = cyclone["unit_circle_mse"]["uniformEigen"]["1e0"]["testAccuracy"]

# %%
control = pendulum["none"]["gaussianElement"]["1e0"]["testAccuracy"]
method_1 = pendulum["none"]["unitPerturb"]["1e0"]["testAccuracy"]
method_2 = pendulum["unit_circle_mse"]["gaussianElement"]["1e0"]["testAccuracy"]
method_3 = pendulum["unit_circle_mse"]["unitPerturb"]["1e0"]["testAccuracy"]

# %%
import scipy.stats as stats
method_list = [method_1, method_2, method_3]
for meth in method_list:
    print(stats.ttest_rel(control, meth))
    #p_value(control, meth)
# Out:
# Ttest_relResult(statistic=15.287537944949912, pvalue=1.0775595326659215e-27)
# Ttest_relResult(statistic=0.1551459170268302, pvalue=0.8770253837539828)
# Ttest_relResult(statistic=14.418856823179377, pvalue=5.800974760901508e-26)

# %%
# prediction error
ocean_results = np.array([0.0, 0.001213, 8e-16])
fluid_results = np.array([0.040631, 0.028442, 0.042345])
cyclone_results = np.array([0.0, 0.0, 0.0770854])
pendulum_results = np.array([0.00022, 0.485757, 0.0004636])

# %%
# validation loss
ocean_results = np.array([0.014, 0.617, 0.009])
fluid_results = np.array([0.0, 0.0, 0.074])
cyclone_results = np.array([0.401, 0.083, 0.126])
pendulum_results = np.array([0.00022, 0.049, 0.002])

# %%
datasets = ["Ocean", "Fluids", "Cyclone", "Pendulum"]
methods = ["eigeninit", "eigenloss", "both"]

t_test = np.vstack((ocean_results, fluid_results, cyclone_results, pendulum_results))

fig, ax = plt.subplots()
im = ax.imshow(t_test)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(methods)), labels=methods)
ax.set_yticks(np.arange(len(datasets)), labels=datasets)

# Rotate the tick labels and set their alignment.
#plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         #rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(datasets)):
    for j in range(len(methods)):
        text = ax.text(j, i, np.round(t_test[i, j], 3),
                       ha="center", va="center", color="w")
plt.savefig("t_test.pdf", transparent=True, bbox_inches='tight', pad_inches=0, dpi=300)
plt.show()

# %% [markdown]
# ## Paired t-tests: final validation losses

# %%
def collect_val_losses(exp: Experiment, num_runs=30, epochs=20):
    vals = []
    for i in tqdm(range(num_runs)):
        loss_dict, _ = exp.run(epochs=epochs)
        vals.append(loss_dict["fwd_val"][-1])
    return np.array(vals)

# %%
# instantiate experiments
ge_exp = Experiment("none", "gaussianElement", 1.0, "cyclone-limited")
init_exp = Experiment("none", "unitPerturb", 1.0, "cyclone-limited")
loss_exp = Experiment("unit_circle_mse", "gaussianElement", 1.0, "cyclone-limited")
both_exp = Experiment("unit_circle_mse", "unitPerturb", 1.0, "cyclone-limited")
new_init_exp = Experiment("none", "unitPerturb_new", 1.0, "cyclone-limited")

# get vals
ge_vals = collect_val_losses(ge_exp)
init_vals = collect_val_losses(init_exp)
loss_vals = collect_val_losses(loss_exp)
both_vals = collect_val_losses(both_exp)
new_init_exp = collect_val_losses(new_init_exp)
# Out:
# ...
#  17%|█▋        | 5/30 [13:45<1:09:13, 166.14s/it]

# %%
new_init_vals = new_init_exp

# %%
from scipy.stats import t

def p_value(control, method):
    #Compute the difference between the results
    diff = [y - x for y, x in zip(control, method)]
    #Compute the mean of differences
    d_bar = np.mean(diff)
    #compute the variance of differences
    sigma2 = np.var(diff)
    #compute the number of data points used for training 
    n1 = 1095
    #compute the number of data points used for testing 
    n2 = 210
    #compute the total number of data points
    n = 1305
    #compute the modified variance
    sigma2_mod = sigma2 * (1/n + n2/n1)
    #compute the t_static
    t_static =  d_bar / np.sqrt(sigma2_mod)
    #Compute p-value and plot the results 
    Pvalue = ((1 - t.cdf(t_static, n-1)))
    print(Pvalue)

# %%
p_value(ge_vals, new_init_vals)
# Out:
# 0.0

# %%
# init, loss, both, new_init
ocean_results = np.array([0.02245, 0.30168, 0.01714])#, 0.00132])
fluid_results = np.array([6e-09, 0.16753, 0.0])#, 0.0])
cyclone_results = np.array([0.01, 0.002, 1e-4])
pendulum_results = np.array([0.04, 0.001, 0.001])

# %%
datasets = ["Ocean", "Fluids", "Cyclone", "Pendulum"]
methods = ["eigeninit", "eigenloss", "both"]

t_test = np.vstack((ocean_results, fluid_results, cyclone_results, pendulum_results))

fig, ax = plt.subplots()
im = ax.imshow(t_test)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(methods)), labels=methods)
ax.set_yticks(np.arange(len(datasets)), labels=datasets)

# Rotate the tick labels and set their alignment.
#plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         #rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(datasets)):
    for j in range(len(methods)):
        text = ax.text(j, i, np.round(t_test[i, j], 3),
                       ha="center", va="center", color="w")
plt.savefig("t_test_bengio.pdf", transparent=True, bbox_inches='tight', pad_inches=0, dpi=300)
plt.show()

# %% [markdown]
# ## Eigenvalues over time

# %%
ge_exp = Experiment("none", "gaussianElement", 1.0, "ocean")
loss_dict, ge_eigvals = ge_exp.run(epochs=100)
print("GE done.")

init_exp = Experiment("none", "unitPerturb", 1.0, "ocean")
_, init_eigvals = init_exp.run(epochs=100)
print("Init done.")

loss_exp = Experiment("unit_circle_mse", "gaussianElement", 1.0, "ocean")
_, loss_eigvals = loss_exp.run(epochs=100)
print("Loss done.")

both_exp = Experiment("unit_circle_mse", "unitPerturb_new", 1.0, "ocean")
_, both_eigvals = both_exp.run(epochs=100)
# Out:
# Exception ignored in: <function _releaseLock at 0x1475bd7a9430>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/logging/__init__.py", line 227, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
# --> 179                         raise Empty
#     180                     self.not_empty.wait(remaining)
#
# Empty:
#
# ...

# %%
ge_mags, init_mags, loss_mags, both_mags = ge_eigvals.copy(), init_eigvals.copy(), loss_eigvals.copy(), both_eigvals.copy()
to_alter = [ge_mags, init_mags, loss_mags, both_mags]
for mag in to_alter:
    for i, epoch in enumerate(mag):
        mag[i] = [np.abs(u.cpu().item()) for u in epoch]
        mag[i].sort(reverse=True)

# %%
ge_mags, init_mags, loss_mags, both_mags = np.array(ge_mags).T, np.array(init_mags).T, np.array(loss_mags).T, np.array(both_mags).T

# %%
import seaborn
import matplotlib as mpl

norm = mpl.colors.Normalize(vmin=0, vmax=1)

fig, axs = plt.subplots(2,2, figsize=(10,6), dpi=600)
seaborn.heatmap(ge_mags, ax=axs[0][0], robust=True)
seaborn.heatmap(init_mags, ax=axs[0][1], robust=True)
seaborn.heatmap(loss_mags, ax=axs[1][0], robust=True)
seaborn.heatmap(both_mags, ax=axs[1][1], robust=True)
axs[0][0].set_title('Gaussian Element')
axs[0][1].set_title('Eigeninit (unitPerturb)')
axs[1][0].set_title('Eigenloss (unit_circle_mse)')
axs[1][1].set_title('Both')

for ax in axs:
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Index of Eigenvalue')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Index of Eigenvalue')

plt.subplots_adjust(hspace = 0.6)
plt.savefig('eig_dist.pdf', transparent=True, bbox_inches='tight', pad_inches=0, dpi=300)
