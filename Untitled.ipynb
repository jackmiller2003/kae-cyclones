# %%
import xarray
import numpy as np

# %%
cyclone_ds = xarray.open_dataset("/g/data/x77/ob2720/partition/train/1988304S08077.nc", engine='netcdf4', cache=False, chunks='auto')
time_length = len(cyclone_ds.time)
example = cyclone_ds.to_array().to_numpy()
example = example.transpose((1,0,2,3,4))
example = np.reshape(example, (time_length,20,160,160))
example.shape
# Out:
# (73, 20, 160, 160)

# %%
# !ls /g/data/x77/ob2720/partition/train/
# Out:
# 1979002S04179.nc  1988304S08077.nc  1999021S13113.nc  2009288N07267.nc
# 1979002S16147.nc  1988307N09131.nc  1999021S15149.nc  2009299N12153.nc
# 1979003S10052.nc  1988308N09140.nc  1999024S11138.nc  2009305N14134.nc
# 1979008S14137.nc  1988310S08100.nc  1999029S14096.nc  2009325N06148.nc
# 1979027S15167.nc  1988319N08090.nc  1999031N08092.nc  2010029S12177.nc
# 1979031S12056.nc  1988323N15286.nc  1999033S14118.nc  2010084S09138.nc
# 1979035S19042.nc  1988327N06100.nc  1999040S13160.nc  2010151N14065.nc
# 1979041S19041.nc  1988347S12128.nc  1999040S15147.nc  2010176N16278.nc
# 1979041S19051.nc  1988352S14166.nc  1999043S18038.nc  2010234N11329.nc
# 1979042S05170.nc  1988356N05142.nc  1999045N11138.nc  2010236N12341.nc
# 1979043S11161.nc  1988364S17148.nc  1999048S21152.nc  2010240N15142.nc
# 1979051S16187.nc  1989002S14192.nc  1999056S20035.nc  2010241N25125.nc
# 1979066S13068.nc  1989006S13184.nc  1999057S22203.nc  2010242N14318.nc
# ...
